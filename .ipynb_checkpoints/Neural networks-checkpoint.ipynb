# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %matplotlib inline

# %%
engine = create_engine('sqlite:///cubic_perovskites.db')
with engine.connect() as conn, conn.begin():
    keyvalues = pd.read_sql_table('number_key_values', conn)
    textvalues = pd.read_sql_table('text_key_values', conn)
    keys = pd.read_sql_table('keys', conn)
    systems = pd.read_sql_table('systems',conn)

# %% [markdown]
# ### The cell below return a dataframe for each variable

# %%
CB_ind = keyvalues[(keyvalues.key=='CB_ind')]
gllbsc_ind_gap = keyvalues[(keyvalues.key=='gllbsc_ind_gap')]
CB_dir = keyvalues[(keyvalues.key=='CB_dir')]
VB_dir = keyvalues[(keyvalues.key=='VB_dir')]
VB_ind = keyvalues[(keyvalues.key=='VB_ind')]
gllbsc_dir_gap = keyvalues[(keyvalues.key=='gllbsc_dir_gap')]
heat_of_formation = keyvalues[(keyvalues.key=='heat_of_formation_all')]
standard_energy = keyvalues[(keyvalues.key=='standard_energy')]

# %%
keyvalues
# Out:
#                           key         value     id
# 0                      CB_ind  5.962712e+00      1
# 1              gllbsc_ind_gap  0.000000e+00      1
# 2       heat_of_formation_all  1.200000e+00      1
# 3                      CB_dir  5.962712e+00      1
# 4              gllbsc_dir_gap  0.000000e+00      1
# 5             standard_energy -2.771908e+00      1
# 6                      VB_dir  5.962712e+00      1
# 7                      VB_ind  5.962712e+00      1
# 8                      CB_ind  5.456778e+00      2
# 9              gllbsc_ind_gap  0.000000e+00      2
# 10      heat_of_formation_all  6.000000e-01      2
# 11                     CB_dir  5.456778e+00      2
# 12             gllbsc_dir_gap  0.000000e+00      2
# 13            standard_energy -2.015260e+00      2
# 14                     VB_dir  5.456778e+00      2
# 15                     VB_ind  5.456778e+00      2
# 16                     CB_ind  5.603095e+00      3
# 17             gllbsc_ind_gap  1.000000e+00      3
# 18      heat_of_formation_all  5.400000e-01      3
# 19                     CB_dir  5.333095e+00      3
# 20             gllbsc_dir_gap  1.600000e+00      3
# 21            standard_energy -3.706880e+00      3
# 22                     VB_dir  6.913095e+00      3
# 23                     VB_ind  6.643095e+00      3
# 24                     CB_ind  6.066547e+00      4
# 25             gllbsc_ind_gap  0.000000e+00      4
# 26      heat_of_formation_all  8.800000e-01      4
# 27                     CB_dir  6.066547e+00      4
# 28             gllbsc_dir_gap  0.000000e+00      4
# 29            standard_energy -4.985423e-01      4
# ...                       ...           ...    ...
# 151835        standard_energy -2.106001e+02  19343
# 151836        standard_energy  1.229039e+01  19345
# 151837        standard_energy -5.961527e+01  19346
# 151838        standard_energy -8.376977e+01  19347
# 151839        standard_energy -2.769678e+01  19348
# 151840        standard_energy -2.833570e+01  19349
# 151841        standard_energy -3.135754e+01  19350
# 151842        standard_energy -9.158409e+01  19351
# 151843        standard_energy -1.059644e+01  19352
# 151844        standard_energy -2.069787e+01  19353
# 151845        standard_energy -1.701348e+00  19354
# 151846        standard_energy -5.339914e+00  19355
# 151847        standard_energy -1.878751e+01  19356
# 151848        standard_energy -3.536093e+00  19357
# 151849        standard_energy -4.125344e+01  19358
# 151850        standard_energy -9.158409e+01  19359
# 151851        standard_energy -1.563926e+01  19360
# 151852        standard_energy -2.216518e+01  19361
# 151853        standard_energy -2.056558e+01  19362
# 151854        standard_energy -1.996165e+01  19363
# 151855        standard_energy -2.318368e+01  19364
# 151856        standard_energy -2.710604e+01  19365
# 151857        standard_energy  2.618035e+00  19366
# 151858        standard_energy -1.125391e+01  19367
# 151859        standard_energy  0.000000e+00  19368
# 151860        standard_energy -5.684342e-14  19369
# 151861        standard_energy  0.000000e+00  19370
# 151862        standard_energy  0.000000e+00  19372
# 151863        standard_energy  0.000000e+00  19371
# 151864        standard_energy  5.061803e+00  19373
#
# [151865 rows x 3 columns]

# %% [markdown]
# ### The cells below build a dataframe for all the values.
# id is the ID of the perovskite

# %%
valuelist=[CB_dir,VB_dir,VB_ind,gllbsc_dir_gap,gllbsc_ind_gap,heat_of_formation,standard_energy]
values = CB_ind
for x in valuelist:
    values = pd.merge(values,x,how='outer',on='id')

# %%
values.set_index('id',inplace=True)

# %%
values.columns=['key','CB_ind','key','CB_dir','key','VB_dir','key','VB_ind','key','gllbsc_dir_gap','key','gllbsc_ind_gap','key','heat_of_formation','key','standard_energy']

# %%
values=values.drop(columns='key')

# %% [markdown]
# ### The cells below build dataframe for A_ion, B_ion and Anion, each dataframe contains the ion's electronegativity and first ionization energy
#
# anion's electronegativity and first ionization energy are calculated from average value of each atom

# %%
A_ion = textvalues[(textvalues.key=='A_ion')]
B_ion = textvalues[(textvalues.key=='B_ion')]
anion = textvalues[(textvalues.key=='anion')]

electroneg = pd.read_csv('electronegativity.csv')
electroneg.columns = ['value', 'electronegativity']

A_electroneg=pd.merge(A_ion,electroneg,how='left',on='value')
B_electroneg=pd.merge(B_ion,electroneg,how='left',on='value')

ionization=pd.read_excel('ionization energy.xlsx')

A_values=pd.merge(A_electroneg,ionization,how='left',on='value')
B_values=pd.merge(B_electroneg,ionization,how='left',on='value')

#affinity = pd.read_excel('electron affinities.xlsx')

# %%
A_values.columns=['key','A_ion','id','A_X','A_IE']
B_values.columns=['key','B_ion','id','B_X','B_IE']

# %%
cation_values=pd.merge(A_values,B_values,how='outer',on='id')

# %%
cation_values.head()
# Out:
#    key_x A_ion  id   A_X      A_IE  key_y B_ion   B_X     B_IE
# 0  A_ion    Ti   1  1.54   6.82810  B_ion    As  2.18  9.78860
# 1  A_ion     K   2  0.82   4.34066  B_ion    Sb  2.05  8.60840
# 2  A_ion    Hg   3  2.00  10.43750  B_ion    Nb  1.60  6.75885
# 3  A_ion    Bi   4  2.02   7.28560  B_ion    Sb  2.05  8.60840
# 4  A_ion    Na   5  0.93   5.13908  B_ion    Ag  1.93  7.57620

# %%
anion_electronegativity=[3.04,3.62,3.30666,3.15333,3.44,3.48666,3.17333]
#this is calculated from the average of atom's electronegativity
anion_ionization=[14.53414,14.88631,13.92342,12.53204,13.61806,15.19167,14.22878]
#this is calculated from the average of atom's ionization
anion_data = pd.DataFrame({'value':['N3','O2F','O2N','O2S','O3','OFN','ON2'],'electronegativity':anion_electronegativity,'first ionization energy':anion_ionization})
anion_data
# Out:
#    electronegativity  first ionization energy value
# 0            3.04000                 14.53414    N3
# 1            3.62000                 14.88631   O2F
# 2            3.30666                 13.92342   O2N
# 3            3.15333                 12.53204   O2S
# 4            3.44000                 13.61806    O3
# 5            3.48666                 15.19167   OFN
# 6            3.17333                 14.22878   ON2

# %%
anion_values=pd.merge(anion,anion_data,how='left',on='value')

# %%
anion_values.columns=['key','anion','id','anion_X','anion_IE']

# %%
perovskite_values=pd.merge(anion_values,cation_values,how='outer',on='id')

# %% [markdown]
# ### The cell below get two dataframe: mass and volume
# id is the ID of perovskite

# %%
volume = pd.DataFrame({'id': systems.id, 'volume':systems.volume})
mass = pd.DataFrame({'id': systems.id, 'mass':systems.mass})

# %%
volume.head()
# Out:
#    id     volume
# 0   1  60.301946
# 1   2  69.072728
# 2   3  70.420772
# 3   4  71.053021
# 4   5  73.668620

# %%
perovskite=pd.merge(perovskite_values,volume,how='left',on='id')
perovskite=pd.merge(perovskite,mass,how='left',on='id')

# %%
perovskite=perovskite.drop(columns=['key','key_x','key_y'])

# %%
perovskite.set_index('id',inplace=True)

# %%
perovskite['density']=perovskite['mass']/perovskite['volume']

# %% [markdown]
# In above dataframe, X represents electronegativity, IE represents Ionization Energy.
# Density is calculated from mass/volume

# %%
perovskite.head()
# Out:
#    anion  anion_X  anion_IE A_ion   A_X      A_IE B_ion   B_X     B_IE  \
# id
# 1    O2N  3.30666  13.92342    Ti  1.54   6.82810    As  2.18  9.78860
# 2    O2N  3.30666  13.92342     K  0.82   4.34066    Sb  2.05  8.60840
# 3    O2N  3.30666  13.92342    Hg  2.00  10.43750    Nb  1.60  6.75885
# 4    O2N  3.30666  13.92342    Bi  2.02   7.28560    Sb  2.05  8.60840
# 5    O2N  3.30666  13.92342    Na  0.93   5.13908    Ag  1.93  7.57620
#
#        volume       mass   density
# id
# 1   60.301946  168.80710  2.799364
# 2   69.072728  206.86080  2.994826
# 3   70.420772  339.50190  4.821048
# 4   71.053021  376.74290  5.302278
# 5   73.668620  176.86327  2.400795

# %%
# remove all the NaN data
values = values[(values.CB_ind > 0.0)]

# %%
values.head()
# Out:
#       CB_ind    CB_dir    VB_dir    VB_ind  gllbsc_dir_gap  gllbsc_ind_gap  \
# id
# 1   5.962712  5.962712  5.962712  5.962712             0.0             0.0
# 2   5.456778  5.456778  5.456778  5.456778             0.0             0.0
# 3   5.603095  5.333095  6.913095  6.643095             1.6             1.0
# 4   6.066547  6.066547  6.066547  6.066547             0.0             0.0
# 5   5.539498  5.539498  5.539498  5.539498             0.0             0.0
#
#     heat_of_formation  standard_energy
# id
# 1                1.20        -2.771908
# 2                0.60        -2.015260
# 3                0.54        -3.706880
# 4                0.88        -0.498542
# 5                1.78         3.552433

# %%
values[(values.gllbsc_dir_gap > 0.0)].count()
# Out:
# CB_ind               735
# CB_dir               735
# VB_dir               735
# VB_ind               735
# gllbsc_dir_gap       735
# gllbsc_ind_gap       735
# heat_of_formation    735
# standard_energy      735
# dtype: int64

# %% [markdown]
# only 735 lines positive bandgap data

# %%
data_total=pd.merge(perovskite,values,how='outer',left_index=True,right_index=True)

# %%
data_total.head()
# Out:
#    anion  anion_X  anion_IE A_ion   A_X      A_IE B_ion   B_X     B_IE  \
# id
# 1    O2N  3.30666  13.92342    Ti  1.54   6.82810    As  2.18  9.78860
# 2    O2N  3.30666  13.92342     K  0.82   4.34066    Sb  2.05  8.60840
# 3    O2N  3.30666  13.92342    Hg  2.00  10.43750    Nb  1.60  6.75885
# 4    O2N  3.30666  13.92342    Bi  2.02   7.28560    Sb  2.05  8.60840
# 5    O2N  3.30666  13.92342    Na  0.93   5.13908    Ag  1.93  7.57620
#
#        volume       mass   density    CB_ind    CB_dir    VB_dir    VB_ind  \
# id
# 1   60.301946  168.80710  2.799364  5.962712  5.962712  5.962712  5.962712
# 2   69.072728  206.86080  2.994826  5.456778  5.456778  5.456778  5.456778
# 3   70.420772  339.50190  4.821048  5.603095  5.333095  6.913095  6.643095
# 4   71.053021  376.74290  5.302278  6.066547  6.066547  6.066547  6.066547
# 5   73.668620  176.86327  2.400795  5.539498  5.539498  5.539498  5.539498
#
#     gllbsc_dir_gap  gllbsc_ind_gap  heat_of_formation  standard_energy
# id
# 1              0.0             0.0               1.20        -2.771908
# 2              0.0             0.0               0.60        -2.015260
# 3              1.6             1.0               0.54        -3.706880
# 4              0.0             0.0               0.88        -0.498542
# 5              0.0             0.0               1.78         3.552433

# %% [markdown]
# the dataframe 'data_total' is a collection of all the data

# %% [markdown]
# ### Neural networks

# %%
traindata,testdata = train_test_split(data_total)

# %%
traindata.head()
# Out:
#       anion  anion_X  anion_IE A_ion   A_X     A_IE B_ion   B_X     B_IE  \
# id
# 17281    N3  3.04000  14.53414     Y  1.22  6.21710    Al  1.61  5.98577
# 3689    OFN  3.48666  15.19167    Cr  1.66  6.76650    In  1.78  5.78636
# 16679    N3  3.04000  14.53414    Zr  1.33  6.63390    Cs  0.79  3.89390
# 13676    O3  3.44000  13.61806    Ni  1.91  7.63980     V  1.63  6.74620
# 11260   O2F  3.62000  14.88631    Hf  1.30  6.82507    Si  1.90  8.15169
#
#           volume       mass   density    CB_ind    CB_dir    VB_dir    VB_ind  \
# id
# 17281  55.522209  157.90754  2.844043  5.235761  5.235761  5.235761  5.235761
# 3689   78.155933  215.82050  2.761409  5.801455  5.801455  5.801455  5.801455
# 16679  79.449568  266.14950  3.349918  4.980005  4.980005  4.980005  4.980005
# 13676  53.086269  157.63310  2.969376  5.834828  5.834828  5.834828  5.834828
# 11260  68.322690  257.57270  3.769944  6.255765  6.255765  6.255765  6.255765
#
#        gllbsc_dir_gap  gllbsc_ind_gap  heat_of_formation  standard_energy
# id
# 17281             0.0             0.0               0.98        -0.497114
# 3689              0.0             0.0               1.28        -0.209755
# 16679             0.0             0.0               3.84        13.092023
# 13676             0.0             0.0               0.72        -4.466964
# 11260             0.0             0.0               1.48        -6.551044
